# %%
# 2.1파이썬 기초

import this
True != '1' #boolean type is not character type
True and True
True and False
# Number and string
type(1)
type('1')
"인천시 연수구 동춘동"
til = 'Today I learned'
til.lower() # lower the words
til.upper() # upper the words
lang = []
lang.append("python")
lang.append('java')
lang.append('c')
lang
lang[-2]
for i in lang:
  if i == 'python':
    print(i)
  else:
    print("기타")
count = len(lang)
for i in range(count):
  print(lang[i])
for i in range(1,10):
  if i % 2 == 0:
    print('python')
  else:
    print('java')
for i,value in enumerate(lang):
  print(i, value)
address = ' 인천시 연수구 '
address = address.strip()
address
len(address)
address_list = address.split()
address
address[:2]
address.startswith("인천")
"인천" in address
address_list[1]
" ".join(address_list)
"인천" in address_list
"연수구" in address_list
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# python
# 기타
# 기타
# python
# java
# c
# java
# python
# java
# python
# java
# python
# java
# ...

# %%
# 2.2 판다스 기초
# 판다스는 panel data system 패널자료의 약자이다.
# 행과 열로 된 엑셀과도 비슷한 데이터 분류
# 대용량데이터를 엑셀보다 더 빠르게 처리 가능

# 지금부터는 10minute to pandas
import numpy as np
import pandas as pd

s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
dates = pd.date_range('20130101', periods=6)

dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns =list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.763427  0.160781  0.075577 -0.152147
# 2013-01-02 -0.582881 -0.282935  0.557161  0.334381
# 2013-01-03  1.092472 -0.592933  0.954650  0.235926
# 2013-01-04  0.492940  0.377780 -0.002376  1.029051
# 2013-01-05 -0.319843 -1.132700 -0.953261 -0.439973
# 2013-01-06  1.975465 -0.173128  1.139791  0.018133

# %%
df2 = pd.DataFrame({
    'a' : 1.0,
    'b' : pd.Timestamp('20130102'),
    'c' : pd.Series(1, index=list(range(4)), dtype='float32'),
    'd' : np.array([3]*4, dtype='int32'),
    'e' : pd.Categorical(['test','train','test','train']),
    'f' : 'foo'
})

df2
# Out:
#      a          b    c  d      e    f
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# a           float64
# b    datetime64[ns]
# c           float32
# d             int32
# e          category
# f            object
# dtype: object

# %%
df2.head()
df2.tail(3)
# Out:
#      a          b    c  d      e    f
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.76342656,  0.16078078,  0.07557738, -0.15214735],
#        [-0.58288075, -0.2829349 ,  0.55716111,  0.33438146],
#        [ 1.09247184, -0.59293295,  0.95465021,  0.2359257 ],
#        [ 0.49293996,  0.37778049, -0.00237562,  1.02905058],
#        [-0.31984318, -1.13270025, -0.95326054, -0.43997332],
#        [ 1.97546534, -0.17312762,  1.139791  ,  0.01813302]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.570263 -0.273856  0.295257  0.170895
# std    0.939427  0.540961  0.763187  0.503635
# min   -0.582881 -1.132700 -0.953261 -0.439973
# 25%   -0.116647 -0.515433  0.017113 -0.109577
# 50%    0.628183 -0.228031  0.316369  0.127029
# 75%    1.010211  0.077304  0.855278  0.309768
# max    1.975465  0.377780  1.139791  1.029051

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.763427   -0.582881    1.092472    0.492940   -0.319843    1.975465
# B    0.160781   -0.282935   -0.592933    0.377780   -1.132700   -0.173128
# C    0.075577    0.557161    0.954650   -0.002376   -0.953261    1.139791
# D   -0.152147    0.334381    0.235926    1.029051   -0.439973    0.018133

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.152147  0.075577  0.160781  0.763427
# 2013-01-02  0.334381  0.557161 -0.282935 -0.582881
# 2013-01-03  0.235926  0.954650 -0.592933  1.092472
# 2013-01-04  1.029051 -0.002376  0.377780  0.492940
# 2013-01-05 -0.439973 -0.953261 -1.132700 -0.319843
# 2013-01-06  0.018133  1.139791 -0.173128  1.975465

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-05 -0.319843 -1.132700 -0.953261 -0.439973
# 2013-01-03  1.092472 -0.592933  0.954650  0.235926
# 2013-01-02 -0.582881 -0.282935  0.557161  0.334381
# 2013-01-06  1.975465 -0.173128  1.139791  0.018133
# 2013-01-01  0.763427  0.160781  0.075577 -0.152147
# 2013-01-04  0.492940  0.377780 -0.002376  1.029051

# %%
df['A']
# Out:
# 2013-01-01    0.763427
# 2013-01-02   -0.582881
# 2013-01-03    1.092472
# 2013-01-04    0.492940
# 2013-01-05   -0.319843
# 2013-01-06    1.975465
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.763427  0.160781  0.075577 -0.152147
# 2013-01-02 -0.582881 -0.282935  0.557161  0.334381
# 2013-01-03  1.092472 -0.592933  0.954650  0.235926

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.582881 -0.282935  0.557161  0.334381
# 2013-01-03  1.092472 -0.592933  0.954650  0.235926
# 2013-01-04  0.492940  0.377780 -0.002376  1.029051

# %%
df.loc[dates[0]]
# Out:
# A    0.763427
# B    0.160781
# C    0.075577
# D   -0.152147
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.763427  0.160781
# 2013-01-02 -0.582881 -0.282935
# 2013-01-03  1.092472 -0.592933
# 2013-01-04  0.492940  0.377780
# 2013-01-05 -0.319843 -1.132700
# 2013-01-06  1.975465 -0.173128

# %%
df.loc['20130102':'20130104', ['A','B']]
# Out:
#                    A         B
# 2013-01-02 -0.582881 -0.282935
# 2013-01-03  1.092472 -0.592933
# 2013-01-04  0.492940  0.377780

# %%
df.loc[dates[0],'A']
# Out:
# 0.7634265636663778

# %%
df.at[dates[0], 'A']
# Out:
# 0.7634265636663778

# %%
df.iloc[3]
# Out:
# A    0.492940
# B    0.377780
# C   -0.002376
# D    1.029051
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A        B
# 2013-01-04  0.492940  0.37778
# 2013-01-05 -0.319843 -1.13270

# %%
df.iloc[[1,2,4], [0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.582881  0.557161
# 2013-01-03  1.092472  0.954650
# 2013-01-05 -0.319843 -0.953261

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.160781  0.075577
# 2013-01-02 -0.282935  0.557161
# 2013-01-03 -0.592933  0.954650
# 2013-01-04  0.377780 -0.002376
# 2013-01-05 -1.132700 -0.953261
# 2013-01-06 -0.173128  1.139791

# %%
df.iloc[1,1]
# Out:
# -0.282934901232722

# %%
df.iat[1,1]
# Out:
# -0.282934901232722

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.763427  0.160781  0.075577 -0.152147
# 2013-01-03  1.092472 -0.592933  0.954650  0.235926
# 2013-01-04  0.492940  0.377780 -0.002376  1.029051
# 2013-01-06  1.975465 -0.173128  1.139791  0.018133

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.763427  0.160781  0.075577       NaN
# 2013-01-02       NaN       NaN  0.557161  0.334381
# 2013-01-03  1.092472       NaN  0.954650  0.235926
# 2013-01-04  0.492940  0.377780       NaN  1.029051
# 2013-01-05       NaN       NaN       NaN       NaN
# 2013-01-06  1.975465       NaN  1.139791  0.018133

# %%
df2 = df.copy()

df2['E'] = ['ONE','ONE','TWO','THREE','FOUR','THREE']

df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.763427  0.160781  0.075577 -0.152147    ONE
# 2013-01-02 -0.582881 -0.282935  0.557161  0.334381    ONE
# 2013-01-03  1.092472 -0.592933  0.954650  0.235926    TWO
# 2013-01-04  0.492940  0.377780 -0.002376  1.029051  THREE
# 2013-01-05 -0.319843 -1.132700 -0.953261 -0.439973   FOUR
# 2013-01-06  1.975465 -0.173128  1.139791  0.018133  THREE

# %%
df2[df2['E'].isin(['TWO','FOUR'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  1.092472 -0.592933  0.954650  0.235926   TWO
# 2013-01-05 -0.319843 -1.132700 -0.953261 -0.439973  FOUR

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))

s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df.at[dates[0], 'A'] = 0
df.iat[0,1] = 0
df.loc[:,'D'] = np.array([5]* len(df))
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  0.075577  5  NaN
# 2013-01-02 -0.582881 -0.282935  0.557161  5  1.0
# 2013-01-03  1.092472 -0.592933  0.954650  5  2.0
# 2013-01-04  0.492940  0.377780 -0.002376  5  3.0
# 2013-01-05 -0.319843 -1.132700 -0.953261  5  4.0
# 2013-01-06  1.975465 -0.173128  1.139791  5  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.075577 -5  NaN
# 2013-01-02 -0.582881 -0.282935 -0.557161 -5 -1.0
# 2013-01-03 -1.092472 -0.592933 -0.954650 -5 -2.0
# 2013-01-04 -0.492940 -0.377780 -0.002376 -5 -3.0
# 2013-01-05 -0.319843 -1.132700 -0.953261 -5 -4.0
# 2013-01-06 -1.975465 -0.173128 -1.139791 -5 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0] : dates[1], 'E'] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.075577  5  NaN  1.0
# 2013-01-02 -0.582881 -0.282935  0.557161  5  1.0  1.0
# 2013-01-03  1.092472 -0.592933  0.954650  5  2.0  NaN
# 2013-01-04  0.492940  0.377780 -0.002376  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02 -0.582881 -0.282935  0.557161  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.075577  5  5.0  1.0
# 2013-01-02 -0.582881 -0.282935  0.557161  5  1.0  1.0
# 2013-01-03  1.092472 -0.592933  0.954650  5  2.0  5.0
# 2013-01-04  0.492940  0.377780 -0.002376  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.443026
# B   -0.300653
# C    0.295257
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.268894
# 2013-01-02    1.138269
# 2013-01-03    1.690838
# 2013-01-04    1.773669
# 2013-01-05    1.318839
# 2013-01-06    2.588426
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5, np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03  0.092472 -1.592933 -0.045350  4.0  1.0
# 2013-01-04 -2.507060 -2.622220 -3.002376  2.0  0.0
# 2013-01-05 -5.319843 -6.132700 -5.953261  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  0.075577   5   NaN
# 2013-01-02 -0.582881 -0.282935  0.632738  10   1.0
# 2013-01-03  0.509591 -0.875868  1.587389  15   3.0
# 2013-01-04  1.002531 -0.498087  1.585013  20   6.0
# 2013-01-05  0.682688 -1.630788  0.631753  25  10.0
# 2013-01-06  2.658153 -1.803915  1.771544  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.558346
# B    1.510481
# C    2.093052
# D    0.000000
# F    4.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    6
# 1    4
# 2    3
# 3    5
# 4    2
# 5    1
# 6    4
# 7    0
# 8    0
# 9    6
# dtype: int64

# %%
s.value_counts()
# Out:
# 6    2
# 4    2
# 0    2
# 5    1
# 3    1
# 2    1
# 1    1
# dtype: int64

# %%
s = pd.Series(['A','B','C','Aaba','Baca', np.nan, 'CABA','dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0  2.167202  1.376164  1.289253  0.313188
# 1  0.814494 -1.219720 -0.352924  0.402805
# 2  1.014605  1.167939 -0.934653  1.426502
# 3 -1.383523 -1.112712  0.878333 -0.204990
# 4  2.497562 -0.262920  1.965952 -0.099115
# 5  0.877787 -1.318076 -2.444956 -2.373550
# 6 -0.366827 -1.253083  0.922281  0.488106
# 7 -0.352179 -0.763542 -0.565959 -1.628891
# 8  0.743803 -0.434875  1.497106  0.684515
# 9  0.297853 -0.062405 -0.483721  1.313947

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  2.167202  1.376164  1.289253  0.313188
# 1  0.814494 -1.219720 -0.352924  0.402805
# 2  1.014605  1.167939 -0.934653  1.426502
# 3 -1.383523 -1.112712  0.878333 -0.204990
# 4  2.497562 -0.262920  1.965952 -0.099115
# 5  0.877787 -1.318076 -2.444956 -2.373550
# 6 -0.366827 -1.253083  0.922281  0.488106
# 7 -0.352179 -0.763542 -0.565959 -1.628891
# 8  0.743803 -0.434875  1.497106  0.684515
# 9  0.297853 -0.062405 -0.483721  1.313947

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1,2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4,5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1,2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4,5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar','foo','foo'],
        'B': ['one', 'one', 'two','three', 'two','two','one','three'],
        'C': np.random.randn(8),
        'D': np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one -1.127132  0.855434
# 1  bar    one  0.232478  2.139168
# 2  foo    two  2.236865  2.322500
# 3  bar  three -1.753423 -0.639933
# 4  foo    two  0.274726  0.756797
# 5  bar    two -0.514725  0.969912
# 6  foo    one -0.956491  0.158800
# 7  foo  three -0.379535 -1.020362

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -2.035670  2.469147
# foo  0.048434  3.073169

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.232478  2.139168
#     three -1.753423 -0.639933
#     two   -0.514725  0.969912
# foo one   -2.083623  1.014234
#     three -0.379535 -1.020362
#     two    2.511592  3.079297

# %%
tuples = list(
    zip(
        *[
          ['bar', 'bar', 'baz', 'baz','foo','foo','qux', 'qux'],
          ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']
        ]
    )
)

# %%
# 10 miniute to pandas 스킵하고 pandas cheet sheet 강의 시작!

# DataFrame
df = pd.DataFrame(
    {'a' : [4,5,6],
    'b' : [7,8,9],
    'c' : [10,11,12]},
    index = [1,2,3]
)

df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
# Series

df['a'] # series는 벡터다. (1차원의 자료구조)
# Out:
# 1    4
# 2    5
# 3    6
# Name: a, dtype: int64

# %%
df[['a']] # dataframe은 행렬이다. 시리즈가 데이터 프레임(2차원의 자료구조) 형태로 바뀜
# Out:
#    a
# 1  4
# 2  5
# 3  6

# %%
 # Subset - 행 또는 컬럼을 기준으로 값을 가져옴

 df[df['a']>4]
# Out:
#    a  b   c
# 2  5  8  11
# 3  6  9  12

# %%
df['a']
# Out:
# 1    4
# 2    5
# 3    6
# Name: a, dtype: int64

# %%
df[['a','b']] # 두개 이상의 컬럼을 가져올때는 데이터 프레임 형태로 가져올 수 있도록 컬럼의 값을 리스트 형태로 받아와야 함
# Out:
#    a  b
# 1  4  7
# 2  5  8
# 3  6  9

# %%
# Summarize Data

df['a'].value_counts() # 값 빈도수를 계산해 줌
# Out:
# 6    1
# 5    1
# 4    1
# Name: a, dtype: int64

# %%
len(df)
# Out:
# 3

# %%
# Reshaping
# sort_values, drop
df['a'].sort_values()
# Out:
# 1    4
# 2    5
# 3    6
# Name: a, dtype: int64

# %%
df.sort_values('a', ascending=False)
# Out:
#    a  b   c
# 3  6  9  12
# 2  5  8  11
# 1  4  7  10

# %%
df = df.drop(['c'], axis=1) # axis=0 행을기준 axics=1 열을 기준
df
# Out:
#    a  b
# 1  4  7
# 2  5  8
# 3  6  9

# %%
# Group Data
# Groupby, pivot_table 데이터를 집계할 때 사용
df.groupby(['a'])['b'].agg(['mean','sum','count'])
# Out:
#    mean  sum  count
# a
# 4     7    7      1
# 5     8    8      1
# 6     9    9      1

# %%
df.groupby(['a'])['b'].describe()
# Out:
#    count  mean  std  min  25%  50%  75%  max
# a
# 4    1.0   7.0  NaN  7.0  7.0  7.0  7.0  7.0
# 5    1.0   8.0  NaN  8.0  8.0  8.0  8.0  8.0
# 6    1.0   9.0  NaN  9.0  9.0  9.0  9.0  9.0

# %%
pd.pivot_table(df, index='a', values='b', aggfunc='sum') # aggfunc='mean'이 기본값임임
# Out:
#    b
# a
# 4  7
# 5  8
# 6  9

# %%
# Plotting

df.plot.area() # 기타 등으로 시각화 구현~
